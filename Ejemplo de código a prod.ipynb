# %% [markdown]
# # Ejemplo visualizador de Código en `Python` con `Github`

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generar datos
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Crear gráfico
plt.plot(x, y)
plt.title('Gráfico de Seno')
plt.xlabel('X')
plt.ylabel('Y')

# Mostrar gráfico
plt.show()
